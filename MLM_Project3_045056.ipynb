# %% [markdown]
# ## Project Report : Cluster Analysis of Global Superstore Dataset

# %% [markdown]
# Project Objectives:
# 1. Objective 1: Utilize clustering techniques to partition the dataset into distinct segments or
# clusters, driven by inherent similarities or patterns present within the data.
# 2. Objective 2: Explore the dataset to determine the optimal number of segments or clusters
# required to effectively segment the data and extract meaningful insights.
# 3. Objective 3: Evaluate the attributes of each identified segment or cluster, examining their unique characteristics and uncovering specific patterns or trends within each cluster.
#
# Data dimensions
#
# The dataset comprises 51,291 entries and 23 columns. Each row denotes health-related information
# for an individual.
#
# The columns encompass:
#
# • category: The category to which the product belongs.
#
# • city: The city where the transaction took place or the customer is located.
#
# • country: The country where the transaction took place or the customer is located.
#
# • customer_id: Unique identifier for each customer.
#
# • customer_name: Name of the customer.
#
# • discount: The discount applied to the product in the transaction.
#
# • market: The market or market segment in which the transaction occurred.
#
# • ji_lu_shu: Possibly a numeric identifier or code for a specific record or transaction.
#
# • order_date: The date when the order was placed.
#
# • order_id: Unique identifier for each order.
#
# • order_priority: Priority level assigned to the order.
#
# • product_id: Unique identifier for each product.
#
# • product_name: Name of the product.
#
# • profit: The profit generated from the transaction.
#
# • quantity: The quantity of the product sold in the transaction.
#
# • region: The region where the transaction took place.
#
# • row_id: Unique identifier for each row or record in the dataset.
#
# • segment: The segment or category to which the customer belongs.
#
# • ship_date: The date when the product was shipped.
#
# • ship_mode: The mode of shipping for the product.
#
# • shipping_cost: The cost of shipping for the transaction.
#
# • state: The state where the transaction took place or the customer is located.
#
# • sub_category: The sub-category to which the product belongs.
#
# • year: The year in which the transaction occurred.
#
# • market2: Possibly another market or market segment identifier.
#
# • weeknum: The week number in which the transaction occurred.
#
#
# Source of data
#
# The data was picked up from Dataworld.
#
# Link of the dataset
#
# 2. Variable Description
#
# Based on the provided columns, here’s the categorization:
# Non-Categorical Variables: - discount - ji_lu_shu - order_id - profit - quantity - row_id - sales -
# shipping_cost - year - market2 - weeknum
# Nominal Type Variables: - customer_name - market - product_name - region - state - sub_category
# Categorical Variables: - order_priority - segment - ship_mode

# %% [markdown]
# **3 Data Preprocessing:**
#
# a) Missing Data Info & Treatment:
#
# city 2
#
# customer_id 1
#
# discount 1
#
# order_priority 5
#
# product_id 4
#
# product_name 3
#
# profit 2
#
# quantity 4
#
# segment 2
#
# ship_date 3
#
# ship_mode 2
#
# shipping_cost 4
#
# sub_category 5
#
# market2 5
#
# weeknum 8
#
# b) Numeric Encoding of Categorical Data:
#
#
# *   Alpha-Numeric Variables: All categorical variables are already encoded numerically.
# *   Numeric Assignment for Alpha-Numeric Data: No additional numeric assignment is necessary since the data is already encoded numerically.
#
# c.) Outlier Detection and Treatment for Non-Categorical Data:
#
# *   Detection of Outliers: Box plots were utilized to identify outliers in non-categorical variables.
# *   Treatment of Outliers: Outliers identified via box plots were addressed through normalization
# using Min-Max scaling.
#
# d.) Division of Data into Training and Testing Sets:
# *   Data Splitting: The division into training and testing datasets was not conducted since it’s
# not applicable for clustering analysis.
# *   Variable Selection: Only numerical encoded variables were included for subsequent analysis.

# %% [markdown]
# ## Clustering Evaluation: Decision Tree vs Random Forest
#
# This report compares the performance of two clustering approaches: Decision Tree and Random Forest.
#
# **Decision Tree Clustering**
#
# * The decision tree model achieves a high overall accuracy of 91% on the data. However, a closer look reveals limitations:
#     * Precision and recall for classes 0 and 2 are zero, indicating the model struggles to identify these clusters effectively.
#     * While the weighted average F1-score is 0.86, the macro average F1-score is only 0.32, suggesting a significant imbalance in performance across clusters.
#
# **Random Forest Clustering**
#
# * The random forest model achieves a perfect score (1.0) for all metrics (precision, recall, F1-score) on the training set. This suggests ideal performance in separating the training data into clusters.
# * However, the testing set results paint a different picture:
#     * Overall accuracy remains high at 90%, but performance varies across clusters.
#     * Class 0 has particularly low precision (0.37), indicating the model often misclassifies points into this cluster.
#
# **Performance Comparison and Considerations**
#
# * Both models struggle with identifying certain clusters, particularly for classes 0 and 2 in the decision tree and class 0 in the random forest.
# * The decision tree offers a faster training time (0.05 seconds) compared to the random forest (6.8 seconds). However, the random forest may potentially benefit from hyperparameter tuning to improve generalization to unseen data.
# * Notably, the random forest model lacks a cross-validation accuracy score, making it difficult to assess its performance on unseen data reliably.

# %% [markdown]
# ##  In-Depth Clustering Evaluation: Decision Tree vs Random Forest
#
# This report delves deeper into the performance of two clustering approaches: Decision Tree and Random Forest. It analyzes their strengths, weaknesses, and identifies areas for improvement.
#
# **Decision Tree Clustering Analysis**
#
# * While the decision tree boasts a high overall accuracy of 91%, a closer inspection reveals a concerning bias towards class 1.
#     * Precision and recall for classes 0 and 2 are zero, indicating the model consistently misclassifies data points belonging to these clusters. This suggests the model might be overfitting to the dominant class (class 1) in the training data and failing to generalize effectively to other clusters.
#     * The significant difference between the macro average F1-score (0.32) and the weighted average F1-score (0.86) further emphasizes this class imbalance.
#
# **Random Forest Clustering Analysis**
#
# * The random forest model presents a contrasting picture. It achieves a seemingly perfect score (1.0) on all metrics (precision, recall, F1-score) for the training set. This suggests the model flawlessly separated the training data into distinct clusters.
# * However, the evaluation on the testing set exposes a crucial limitation:
#     * Overall accuracy remains high at 90%, but performance varies dramatically across clusters. Class 0, in particular, suffers from low precision (0.37). This indicates the model frequently misclassifies points into this cluster, suggesting potential overfitting to the training data or limitations in capturing the underlying structure of this specific cluster.
#
# **Performance Comparison and Considerations**
#
# * Both models demonstrate weaknesses in identifying specific clusters. The decision tree struggles with classes 0 and 2, while the random forest struggles with class 0. This suggests that neither model effectively captures the entire data distribution.
# * The decision tree offers a significant advantage in training time (0.05 seconds) compared to the random forest (6.8 seconds). However, the random forest might benefit from hyperparameter tuning to improve its ability to generalize to unseen data and potentially reduce overfitting.
# * A critical limitation of the random forest model is the lack of a cross-validation accuracy score. This makes it difficult to reliably assess its performance on data it hasn't seen before.
#
# **Overall Conclusion**
#
# While both the decision tree and random forest models achieve high overall accuracy on the training data, their performance on unseen data raises concerns. The decision tree struggles with class imbalance, while the random forest potentially overfits to the training data, particularly for class 0.

# %%
# Required Libraries
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import pandas as pd, numpy as np # For Data Manipulation
import matplotlib.pyplot as plt, seaborn as sns # For Data Visualization
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation

# %%
df = pd.read_csv("/content/df_merge (1).csv")
df
# Out:
#        Unnamed: 0  cluster_number         category              city  \
# 0               0               1  Office Supplies       Los Angeles
# 1               1               1  Office Supplies       Los Angeles
# 2               2               1  Office Supplies       Los Angeles
# 3               3               1  Office Supplies       Los Angeles
# 4               4               1  Office Supplies       Los Angeles
# ...           ...             ...              ...               ...
# 30243       30243               0        Furniture           Bangkok
# 30244       30244               1        Furniture           Bangkok
# 30245       30245               1       Technology      Bacolod City
# 30246       30246               1        Furniture  Ho Chi Minh City
# 30247       30247               1       Technology  Ho Chi Minh City
#
#              country customer_id     customer_name  discount market  \
# 0      United States   LS-172304  Lycoris Saunders      0.00     US
# 1      United States   MV-174854     Mark Van Huff      0.00     US
# 2      United States   CS-121304      Chad Sievert      0.00     US
# 3      United States   CS-121304      Chad Sievert      0.00     US
# 4      United States   AP-109154    Arthur Prichep      0.00     US
# ...              ...         ...               ...       ...    ...
# 30243       Thailand   AM-107051    Anne McFarland      0.27   APAC
# 30244       Thailand   AM-107051    Anne McFarland      0.27   APAC
# 30245    Philippines   BT-113951        Bill Tyler      0.25   APAC
# 30246        Vietnam   TP-211301  Theone Pippenger      0.27   APAC
# 30247        Vietnam   TP-211301  Theone Pippenger      0.47   APAC
#
#        ji_lu_shu  ... goood-1;bad-0    segment            ship_date  \
# 0              1  ...             0   Consumer  2011-01-09T00:00:00
# 1              1  ...             0   Consumer  2011-01-26T00:00:00
# 2              1  ...             0   Consumer  2011-08-09T00:00:00
# 3              1  ...             0   Consumer  2011-08-09T00:00:00
# 4              1  ...             0   Consumer  2011-10-03T00:00:00
# ...          ...  ...           ...        ...                  ...
# 30243          1  ...             0   Consumer  2011-09-03T00:00:00
# 30244          1  ...             0   Consumer  2011-09-03T00:00:00
# 30245          1  ...             0  Corporate  2011-09-20T00:00:00
# 30246          1  ...             0   Consumer  2011-11-14T00:00:00
# 30247          1  ...             0   Consumer  2011-11-14T00:00:00
#
#             ship_mode shipping_cost             state  sub_category    year  \
# 0        Second Class          4.37        California         Paper  2011.0
# 1      Standard Class          0.94        California         Paper  2011.0
# 2      Standard Class          1.81        California         Paper  2011.0
# 3      Standard Class          4.59        California         Paper  2011.0
# 4      Standard Class          1.32        California         Paper  2011.0
# ...               ...           ...               ...           ...     ...
# 30243    Second Class         62.81           Bangkok        Chairs  2011.0
# 30244    Second Class         25.14           Bangkok   Furnishings  2011.0
# 30245     First Class         12.90   Western Visayas        Phones  2011.0
# 30246     First Class        184.98  Ho Chí Minh City        Chairs  2011.0
# 30247     First Class        148.73             Ho Ch           NaN     NaN
#
#              market2  weeknum
# 0      North America      2.0
# 1      North America      4.0
# 2      North America     32.0
# 3      North America     32.0
# 4      North America     40.0
# ...              ...      ...
# 30243           APAC     36.0
# 30244           APAC     36.0
# 30245           APAC     39.0
# 30246           APAC     46.0
# 30247            NaN      NaN
#
# [30248 rows x 31 columns]

# %%
missing_values = ["NaN"]
df = pd.read_csv("/content/df_merge (1).csv", na_values=missing_values)

# %%
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
# Out:
# Unnamed: 0           0
# cluster_number       0
# category             0
# city                 2
# country              0
# customer_id          1
# customer_name        0
# discount             0
# market               0
# ji_lu_shu            0
# order_date           0
# order_id             0
# order_priority       4
# product_id           3
# product_name         2
# profit               2
# quantity             2
# region               0
# row_id               0
# sales                0
# sales-good or bad    0
# goood-1;bad-0        0
# segment              2
# ship_date            2
# ship_mode            2
# shipping_cost        3
# state                3
# sub_category         4
# year                 1
# market2              4
# weeknum              7
# dtype: int64

# %%
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data
# Out:
# 37724    5
# 37       3
# 21182    2
# 34512    2
# 51       1
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv('/content/df_merge (1).csv')

# Display DataFrame information
df.info()

# Get the sum of missing data for each variable
variable_missing_data = df.isna().sum()
print(variable_missing_data)

# Get the sum of missing data for each record, showing the top 5
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5)
print(record_missing_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48718 entries, 0 to 48717
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         48718 non-null  int64
#  1   cluster_number     48718 non-null  int64
#  2   category           48718 non-null  object
#  3   city               48716 non-null  object
#  4   country            48718 non-null  object
#  5   customer_id        48717 non-null  object
#  6   customer_name      48718 non-null  object
#  7   discount           48718 non-null  float64
#  8   market             48718 non-null  object
#  9   ji_lu_shu          48718 non-null  int64
#  10  order_date         48718 non-null  object
#  11  order_id           48718 non-null  object
#  12  order_priority     48713 non-null  object
#  13  product_id         48715 non-null  object
#  14  product_name       48715 non-null  object
#  15  profit             48716 non-null  float64
#  16  quantity           48715 non-null  float64
#  17  region             48718 non-null  object
#  18  row_id             48718 non-null  int64
#  19  sales              48718 non-null  int64
#  20  sales-good or bad  48718 non-null  object
#  21  goood-1;bad-0      48718 non-null  int64
#  22  segment            48716 non-null  object
#  23  ship_date          48716 non-null  object
#  24  ship_mode          48716 non-null  object
#  25  shipping_cost      48714 non-null  float64
#  26  state              48716 non-null  object
#  27  sub_category       48714 non-null  object
#  28  year               48717 non-null  float64
#  29  market2            48713 non-null  object
#  30  weeknum            48711 non-null  float64
# dtypes: float64(6), int64(6), object(19)
# memory usage: 11.5+ MB
# Unnamed: 0           0
# cluster_number       0
# category             0
# city                 2
# country              0
# customer_id          1
# customer_name        0
# discount             0
# market               0
# ji_lu_shu            0
# order_date           0
# order_id             0
# order_priority       5
# product_id           3
# product_name         3
# profit               2
# quantity             3
# region               0
# row_id               0
# sales                0
# sales-good or bad    0
# goood-1;bad-0        0
# segment              2
# ship_date            2
# ship_mode            2
# shipping_cost        4
# state                2
# sub_category         4
# year                 1
# market2              5
# weeknum              7
# dtype: int64
# 48717    3
# 37       3
# 34512    2
# 21182    2
# 32563    1
# dtype: int64

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('/content/df_merge (1).csv')

# Display DataFrame information
df.info()

# Get the sum of missing data for each variable
variable_missing_data = df.isna().sum()
print(variable_missing_data)

# Drop all rows with missing values
cleaned_df = df.dropna()

# Display the information of the cleaned dataset
cleaned_df.info()

# Save the cleaned dataset to a new CSV file if needed
cleaned_df.to_csv('no_missing_data.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51241 entries, 0 to 51240
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         51241 non-null  int64
#  1   cluster_number     51241 non-null  int64
#  2   category           51241 non-null  object
#  3   city               51239 non-null  object
#  4   country            51241 non-null  object
#  5   customer_id        51240 non-null  object
#  6   customer_name      51241 non-null  object
#  7   discount           51241 non-null  float64
#  8   market             51241 non-null  object
#  9   ji_lu_shu          51241 non-null  int64
#  10  order_date         51241 non-null  object
#  11  order_id           51241 non-null  object
#  12  order_priority     51236 non-null  object
#  13  product_id         51237 non-null  object
#  14  product_name       51238 non-null  object
#  15  profit             51239 non-null  float64
#  16  quantity           51237 non-null  float64
#  17  region             51241 non-null  object
#  18  row_id             51241 non-null  int64
#  19  sales              51241 non-null  int64
#  20  sales-good or bad  51241 non-null  object
#  21  goood-1;bad-0      51241 non-null  int64
#  22  segment            51239 non-null  object
#  23  ship_date          51239 non-null  object
#  24  ship_mode          51239 non-null  object
#  25  shipping_cost      51237 non-null  float64
#  26  state              51239 non-null  object
#  27  sub_category       51236 non-null  object
#  28  year               51241 non-null  int64
#  29  market2            51236 non-null  object
#  30  weeknum            51233 non-null  float64
# dtypes: float64(5), int64(7), object(19)
# memory usage: 12.1+ MB
# Unnamed: 0           0
# cluster_number       0
# category             0
# city                 2
# country              0
# customer_id          1
# customer_name        0
# discount             0
# market               0
# ji_lu_shu            0
# order_date           0
# order_id             0
# order_priority       5
# product_id           4
# product_name         3
# profit               2
# quantity             4
# region               0
# row_id               0
# sales                0
# sales-good or bad    0
# goood-1;bad-0        0
# segment              2
# ship_date            2
# ship_mode            2
# shipping_cost        4
# state                2
# sub_category         5
# year                 0
# market2              5
# weeknum              8
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 51194 entries, 0 to 51240
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         51194 non-null  int64
#  1   cluster_number     51194 non-null  int64
#  2   category           51194 non-null  object
#  3   city               51194 non-null  object
#  4   country            51194 non-null  object
#  5   customer_id        51194 non-null  object
#  6   customer_name      51194 non-null  object
#  7   discount           51194 non-null  float64
#  8   market             51194 non-null  object
#  9   ji_lu_shu          51194 non-null  int64
#  10  order_date         51194 non-null  object
#  11  order_id           51194 non-null  object
#  12  order_priority     51194 non-null  object
#  13  product_id         51194 non-null  object
#  14  product_name       51194 non-null  object
#  15  profit             51194 non-null  float64
#  16  quantity           51194 non-null  float64
#  17  region             51194 non-null  object
#  18  row_id             51194 non-null  int64
#  19  sales              51194 non-null  int64
#  20  sales-good or bad  51194 non-null  object
#  21  goood-1;bad-0      51194 non-null  int64
#  22  segment            51194 non-null  object
#  23  ship_date          51194 non-null  object
#  24  ship_mode          51194 non-null  object
#  25  shipping_cost      51194 non-null  float64
#  26  state              51194 non-null  object
#  27  sub_category       51194 non-null  object
#  28  year               51194 non-null  int64
#  29  market2            51194 non-null  object
#  30  weeknum            51194 non-null  float64
# dtypes: float64(5), int64(7), object(19)
# memory usage: 12.5+ MB

# %%
import pandas as pd

# Assuming your file is named 'your_file_name.csv'
file_path = '/content/no_missing_data.csv'

# Read the file into a DataFrame
df = pd.read_csv(file_path)

# Categorical Data [Nominal | Ordinal]
df_cat = df[['cluster_number', 'category', 'city', 'country', 'market', 'ji_lu_shu', 'order_priority', 'product_id', 'product_name', 'region', 'sales-good or bad', 'goood-1;bad-0', 'segment', 'ship_mode', 'state', 'sub_category', 'year', 'market2', 'weeknum']]

# Non-Categorical Data
df_noncat = df[['customer_id', 'customer_name', 'discount', 'order_date', 'order_id', 'profit', 'quantity', 'row_id', 'sales', 'ship_date', 'shipping_cost']]

# %%
df_cat
# Out:
#        cluster_number         category         city        country market  \
# 0                   1  Office Supplies  Los Angeles  United States     US
# 1                   1  Office Supplies  Los Angeles  United States     US
# 2                   1  Office Supplies  Los Angeles  United States     US
# 3                   1  Office Supplies  Los Angeles  United States     US
# 4                   1  Office Supplies  Los Angeles  United States     US
# ...               ...              ...          ...            ...    ...
# 51189               1  Office Supplies  Los Angeles  United States     US
# 51190               1  Office Supplies  Los Angeles  United States     US
# 51191               1  Office Supplies  Los Angeles  United States     US
# 51192               1  Office Supplies  Los Angeles  United States     US
# 51193               1  Office Supplies  Los Angeles  United States     US
#
#        ji_lu_shu order_priority       product_id  \
# 0              1           High  OFF-PA-10002005
# 1              1         Medium  OFF-PA-10002893
# 2              1         Medium  OFF-PA-10000659
# 3              1         Medium  OFF-PA-10001144
# 4              1           High  OFF-PA-10002105
# ...          ...            ...              ...
# 51189          1         Medium  OFF-BI-10000591
# 51190          1            Low  OFF-BI-10002215
# 51191          1           High  OFF-BI-10001524
# 51192          1           High  OFF-BI-10002764
# 51193          1       Critical  OFF-BI-10000285
#
#                                             product_name region  \
# 0                                              Xerox 225   West
# 1              Wirebound Service Call Books, 5 1/2" x 4"   West
# 2      Adams Phone Message Book, Professional, 400 Me...   West
# 3                                             Xerox 1913   West
# 4                                              Xerox 223   West
# ...                                                  ...    ...
# 51189                                Avery Binder Labels   West
# 51190        Wilson Jones Hanging View Binder, White, 1"   West
# 51191  GBC Premium Transparent Covers with Diagonal L...   West
# 51192  Recycled Pressboard Report Cover with Reinforc...   West
# 51193  XtraLife ClearVue Slant-D Ring Binders by Card...   West
#
#       sales-good or bad  goood-1;bad-0    segment       ship_mode       state  \
# 0                   bad              0   Consumer    Second Class  California
# 1                   bad              0   Consumer  Standard Class  California
# 2                   bad              0   Consumer  Standard Class  California
# 3                   bad              0   Consumer  Standard Class  California
# 4                   bad              0   Consumer  Standard Class  California
# ...                 ...            ...        ...             ...         ...
# 51189               bad              0   Consumer    Second Class  California
# 51190               bad              0   Consumer  Standard Class  California
# 51191               bad              0  Corporate        Same Day  California
# 51192               bad              0  Corporate        Same Day  California
# 51193               bad              0  Corporate    Second Class  California
#
#       sub_category  year        market2  weeknum
# 0            Paper  2011  North America      2.0
# 1            Paper  2011  North America      4.0
# 2            Paper  2011  North America     32.0
# 3            Paper  2011  North America     32.0
# 4            Paper  2011  North America     40.0
# ...            ...   ...            ...      ...
# 51189      Binders  2013  North America     16.0
# 51190      Binders  2013  North America     22.0
# 51191      Binders  2013  North America     26.0
# 51192      Binders  2013  North America     26.0
# 51193      Binders  2013  North America     31.0
#
# [51194 rows x 19 columns]

# %%
df_noncat
# Out:
#       customer_id      customer_name  discount           order_date  \
# 0       LS-172304   Lycoris Saunders       0.0  2011-01-07T00:00:00
# 1       MV-174854      Mark Van Huff       0.0  2011-01-21T00:00:00
# 2       CS-121304       Chad Sievert       0.0  2011-08-05T00:00:00
# 3       CS-121304       Chad Sievert       0.0  2011-08-05T00:00:00
# 4       AP-109154     Arthur Prichep       0.0  2011-09-29T00:00:00
# ...           ...                ...       ...                  ...
# 51189   JO-152804      Jas O'Carroll       0.2  2013-04-20T00:00:00
# 51190   CL-125654        Clay Ludtke       0.2  2013-05-29T00:00:00
# 51191   CS-122504    Chris Selesnick       0.2  2013-06-29T00:00:00
# 51192   CS-122504    Chris Selesnick       0.2  2013-06-29T00:00:00
# 51193   BF-110204  Barry Französisch       0.2  2013-08-03T00:00:00
#
#              order_id   profit  quantity  row_id  sales            ship_date  \
# 0      CA-2011-130813   9.3312       3.0   36624     19  2011-01-09T00:00:00
# 1      CA-2011-148614   9.2928       2.0   37033     19  2011-01-26T00:00:00
# 2      CA-2011-118962   9.8418       3.0   31468     21  2011-08-09T00:00:00
# 3      CA-2011-118962  53.2608       2.0   31469    111  2011-08-09T00:00:00
# 4      CA-2011-146969   3.1104       1.0   32440      6  2011-10-03T00:00:00
# ...               ...      ...       ...     ...    ...                  ...
# 51189  US-2013-115819   3.2676       3.0   32906      9  2013-04-25T00:00:00
# 51190  CA-2013-134803   7.3840       4.0   34720     23  2013-06-04T00:00:00
# 51191  CA-2013-161095  11.7488       2.0   35604     34  2013-06-29T00:00:00
# 51192  CA-2013-161095   2.8101       3.0   35603      8  2013-06-29T00:00:00
# 51193  CA-2013-156265   4.7040       2.0   36543     13  2013-08-05T00:00:00
#
#        shipping_cost
# 0               4.37
# 1               0.94
# 2               1.81
# 3               4.59
# 4               1.32
# ...              ...
# 51189           0.85
# 51190           1.49
# 51191           7.40
# 51192           1.35
# 51193           1.51
#
# [51194 rows x 11 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame and contains the columns 'profit', 'quantity', 'sales', and 'shipping_cost'
df_noncat = df[['profit', 'quantity', 'sales', 'shipping_cost']]

# Create vertical boxplot for 'profit'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['profit'])
plt.title('Boxplot of Profit')
plt.ylabel('Profit')
plt.show()

# Create vertical boxplot for 'quantity'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['quantity'])
plt.title('Boxplot of Quantity')
plt.ylabel('Quantity')
plt.show()

# Create vertical boxplot for 'sales'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['sales'])
plt.title('Boxplot of Sales')
plt.ylabel('Sales')
plt.show()

# Create vertical boxplot for 'shipping_cost'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['shipping_cost'])
plt.title('Boxplot of Shipping Cost')
plt.ylabel('Shipping Cost')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# Selecting the columns for Min-Max Scaling
columns_to_scale = ['profit', 'quantity', 'sales', 'shipping_cost']

# Normalization using Min-Max Scaling
mms = MinMaxScaler()
mms_fit = mms.fit_transform(df_noncat[columns_to_scale])
df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=[col+'_mmnorm' for col in columns_to_scale])

# Displaying the normalized DataFrame
df_noncat_minmax_norm
# Out:
#        profit_mmnorm  quantity_mmnorm  sales_mmnorm  shipping_cost_mmnorm
# 0           0.440622         0.153846      0.000839              0.004679
# 1           0.440619         0.076923      0.000839              0.001005
# 2           0.440656         0.153846      0.000928              0.001937
# 3           0.443551         0.076923      0.004903              0.004914
# 4           0.440207         0.000000      0.000265              0.001412
# ...              ...              ...           ...                   ...
# 51189       0.440218         0.153846      0.000398              0.000908
# 51190       0.440492         0.230769      0.001016              0.001594
# 51191       0.440783         0.076923      0.001502              0.007924
# 51192       0.440187         0.153846      0.000353              0.001444
# 51193       0.440313         0.076923      0.000574              0.001615
#
# [51194 rows x 4 columns]

# %%
# Pre-Processed Dataset
df_ppd = pd.merge(df_cat, df_noncat, left_index=True, right_index=True)
df_ppd
# Out:
#        cluster_number         category         city        country market  \
# 0                   1  Office Supplies  Los Angeles  United States     US
# 1                   1  Office Supplies  Los Angeles  United States     US
# 2                   1  Office Supplies  Los Angeles  United States     US
# 3                   1  Office Supplies  Los Angeles  United States     US
# 4                   1  Office Supplies  Los Angeles  United States     US
# ...               ...              ...          ...            ...    ...
# 51189               1  Office Supplies  Los Angeles  United States     US
# 51190               1  Office Supplies  Los Angeles  United States     US
# 51191               1  Office Supplies  Los Angeles  United States     US
# 51192               1  Office Supplies  Los Angeles  United States     US
# 51193               1  Office Supplies  Los Angeles  United States     US
#
#        ji_lu_shu order_priority       product_id  \
# 0              1           High  OFF-PA-10002005
# 1              1         Medium  OFF-PA-10002893
# 2              1         Medium  OFF-PA-10000659
# 3              1         Medium  OFF-PA-10001144
# 4              1           High  OFF-PA-10002105
# ...          ...            ...              ...
# 51189          1         Medium  OFF-BI-10000591
# 51190          1            Low  OFF-BI-10002215
# 51191          1           High  OFF-BI-10001524
# 51192          1           High  OFF-BI-10002764
# 51193          1       Critical  OFF-BI-10000285
#
#                                             product_name region  ...  \
# 0                                              Xerox 225   West  ...
# 1              Wirebound Service Call Books, 5 1/2" x 4"   West  ...
# 2      Adams Phone Message Book, Professional, 400 Me...   West  ...
# 3                                             Xerox 1913   West  ...
# 4                                              Xerox 223   West  ...
# ...                                                  ...    ...  ...
# 51189                                Avery Binder Labels   West  ...
# 51190        Wilson Jones Hanging View Binder, White, 1"   West  ...
# 51191  GBC Premium Transparent Covers with Diagonal L...   West  ...
# 51192  Recycled Pressboard Report Cover with Reinforc...   West  ...
# 51193  XtraLife ClearVue Slant-D Ring Binders by Card...   West  ...
#
#             ship_mode       state sub_category  year        market2 weeknum  \
# 0        Second Class  California        Paper  2011  North America     2.0
# 1      Standard Class  California        Paper  2011  North America     4.0
# 2      Standard Class  California        Paper  2011  North America    32.0
# 3      Standard Class  California        Paper  2011  North America    32.0
# 4      Standard Class  California        Paper  2011  North America    40.0
# ...               ...         ...          ...   ...            ...     ...
# 51189    Second Class  California      Binders  2013  North America    16.0
# 51190  Standard Class  California      Binders  2013  North America    22.0
# 51191        Same Day  California      Binders  2013  North America    26.0
# 51192        Same Day  California      Binders  2013  North America    26.0
# 51193    Second Class  California      Binders  2013  North America    31.0
#
#         profit quantity  sales  shipping_cost
# 0       9.3312      3.0     19           4.37
# 1       9.2928      2.0     19           0.94
# 2       9.8418      3.0     21           1.81
# 3      53.2608      2.0    111           4.59
# 4       3.1104      1.0      6           1.32
# ...        ...      ...    ...            ...
# 51189   3.2676      3.0      9           0.85
# 51190   7.3840      4.0     23           1.49
# 51191  11.7488      2.0     34           7.40
# 51192   2.8101      3.0      8           1.35
# 51193   4.7040      2.0     13           1.51
#
# [51194 rows x 23 columns]

# %% [markdown]
# Decision Tree

# %%
df_ppd_1 = df_ppd[['cluster_number', 'ji_lu_shu', 'year', 'weeknum', 'profit', 'quantity', 'sales', 'shipping_cost']]
df_ppd_1
# Out:
#        cluster_number  ji_lu_shu  year  weeknum   profit  quantity  sales  \
# 0                   1          1  2011      2.0   9.3312       3.0     19
# 1                   1          1  2011      4.0   9.2928       2.0     19
# 2                   1          1  2011     32.0   9.8418       3.0     21
# 3                   1          1  2011     32.0  53.2608       2.0    111
# 4                   1          1  2011     40.0   3.1104       1.0      6
# ...               ...        ...   ...      ...      ...       ...    ...
# 51189               1          1  2013     16.0   3.2676       3.0      9
# 51190               1          1  2013     22.0   7.3840       4.0     23
# 51191               1          1  2013     26.0  11.7488       2.0     34
# 51192               1          1  2013     26.0   2.8101       3.0      8
# 51193               1          1  2013     31.0   4.7040       2.0     13
#
#        shipping_cost
# 0               4.37
# 1               0.94
# 2               1.81
# 3               4.59
# 4               1.32
# ...              ...
# 51189           0.85
# 51190           1.49
# 51191           7.40
# 51192           1.35
# 51193           1.51
#
# [51194 rows x 8 columns]

# %%
# Import
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree  # For Decision Tree Model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, classification_report # For Decision Tree Model Evaluation
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from matplotlib.colors import ListedColormap
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score
from matplotlib.colors import ListedColormap

# %%
# Bifurcation of Input and Output variables
df_inputs = df_ppd[[ 'ji_lu_shu', 'year', 'weeknum', 'profit', 'quantity', 'sales', 'shipping_cost']]; df_inputs
df_output = df_ppd[['cluster_number']]

df_inputs_names = df_inputs.columns; df_inputs_names
df_output_labels = df_output['cluster_number'].unique().astype(str); df_output_labels

# Split the df Data Subset into Training & Testing Sets
train_df_inputs, test_df_inputs, train_df_output, test_df_output = train_test_split(df_inputs, df_output, test_size=0.25, random_state=45056)

# %%
# Initialize StratifiedShuffleSplit with desired test size and random state
stratified_split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=45056)

# Perform the stratified split to get training and testing indices
for train_index, test_index in stratified_split.split(df_inputs, df_output):
    train_df_inputs, test_df_inputs = df_inputs.iloc[train_index], df_inputs.iloc[test_index]
    train_df_output, test_df_output = df_output.iloc[train_index], df_output.iloc[test_index]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
import numpy as np

# Initialize Logistic Regression model with L1 regularization
logreg_l1 = LogisticRegression(penalty='l1', solver='liblinear', random_state=45017)

# Fit the model on the training data
logreg_l1.fit(train_df_inputs, train_df_output.values.ravel())

# Get feature importances from the fitted model
feature_importances = np.abs(logreg_l1.coef_).flatten()

# Calculate the threshold as 20% of the maximum feature importance
threshold = 0.2 * np.max(feature_importances)

# Create a selector object to select features based on non-zero coefficients
selector = SelectFromModel(logreg_l1, threshold=threshold)

# Transform the training and testing input data to select features
train_df_inputs_selected = selector.transform(train_df_inputs)
test_df_inputs_selected = selector.transform(test_df_inputs)

# Get the selected features
selected_features = df_inputs_names[selector.get_support()]

# Print the selected features and the calculated threshold
print("Selected Features:", selected_features)
print("Threshold:", threshold)
# Out:
# Selected Features: Index(['year', 'quantity', 'shipping_cost'], dtype='object')
# Threshold: 0.0039442944289381264
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
# Decision Tree Clustering Model

# Decision Tree : Model (Training Subset)
dtc = DecisionTreeClassifier(criterion='gini', random_state=45056,max_depth=3) # Other Criteria : Entropy,  Log Loss
dtc_model = dtc.fit(train_df_inputs, train_df_output); dtc_model
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=45056)

# %%
# Decision Tree : Model Rules
dtc_model_rules = export_text(dtc_model, feature_names = list(df_inputs_names)); print(dtc_model_rules)
# Out:
# |--- sales <= 216.50
# |   |--- sales <= 110.50
# |   |   |--- sales <= 52.50
# |   |   |   |--- class: 1
# |   |   |--- sales >  52.50
# |   |   |   |--- class: 1
# |   |--- sales >  110.50
# |   |   |--- quantity <= 3.50
# |   |   |   |--- class: 1
# |   |   |--- quantity >  3.50
# |   |   |   |--- class: 1
# |--- sales >  216.50
# |   |--- profit <= 2.85
# |   |   |--- profit <= -70.48
# |   |   |   |--- class: 1
# |   |   |--- profit >  -70.48
# |   |   |   |--- class: 1
# |   |--- profit >  2.85
# |   |   |--- sales <= 478.50
# |   |   |   |--- class: 1
# |   |   |--- sales >  478.50
# |   |   |   |--- class: 1

# %%
# Decision Tree : Feature Importance
dtc_imp_features = pd.DataFrame({'feature': df_inputs_names, 'importance': np.round(dtc_model.feature_importances_, 3)})
dtc_imp_features.sort_values('importance', ascending=False, inplace=True); dtc_imp_features
# Out:
#          feature  importance
# 5          sales       0.860
# 3         profit       0.113
# 4       quantity       0.027
# 0      ji_lu_shu       0.000
# 1           year       0.000
# 2        weeknum       0.000
# 6  shipping_cost       0.000

# %%
# Decision Tree : Model Prediction (Training Subset)
dtc_model_predict = dtc_model.predict(train_df_inputs); dtc_model_predict
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
# Decision Tree : Prediction (Testing Subset)
dtc_predict = dtc_model.predict(test_df_inputs); dtc_predict
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
# Decision Tree : Model Evaluation (Training Subset)
dtc_model_conf_mat = pd.DataFrame(confusion_matrix(train_df_output, dtc_model_predict)); dtc_model_conf_mat
dtc_model_perf = classification_report(train_df_output, dtc_model_predict); print(dtc_model_perf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      3544
#            1       0.91      1.00      0.95     37076
#            2       0.00      0.00      0.00       335
#
#     accuracy                           0.91     40955
#    macro avg       0.30      0.33      0.32     40955
# weighted avg       0.82      0.91      0.86     40955
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Decision Tree : Plot [Training Subset]
train_subset_dtc_plot = plot_tree(dtc_model, feature_names=df_inputs_names, class_names=df_output_labels, rounded=True, filled=True, fontsize=8)
plt.show()

# %%
# Set up the plot
ax = plt.axes()

# Plot the confusion matrix with annotations in integer format
sns.heatmap(dtc_model_conf_mat, annot=True, fmt='d', cmap='Paired')

# Set labels and title
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Decision Tree : Confusion Matrix')

# Show the plot
plt.show()

# %%
# Cross Validation
from sklearn.model_selection import cross_val_score

# Define your decision tree classifier with desired parameters
dtc_cv = DecisionTreeClassifier(criterion='gini', random_state=45011)

# Perform 5-fold cross-validation
cv_scores = cross_val_score(dtc_cv, df_inputs, df_output.values.ravel(), cv=20)
print("Cross-Validation Scores:", cv_scores)
print("Average Cross-Validation Score:", np.mean(cv_scores))
# Out:
# Cross-Validation Scores: [0.82929688 0.84765625 0.846875   0.85       0.853125   0.85390625
#  0.8578125  0.84375    0.70742187 0.73164063 0.74023438 0.78632813
#  0.84804687 0.83046875 0.82766706 0.83509183 0.83118406 0.80734662
#  0.82493161 0.82532239]
# Average Cross-Validation Score: 0.818905303585385

# %%
from sklearn.metrics import f1_score

# Compute F1 score
f1 = f1_score(test_df_output, dtc_predict, average='macro')  # or 'weighted' for weighted F1 score
print("F1 Score:", f1)

# Weighted F1 score
weighted_f1 = f1_score(test_df_output, dtc_predict, average='weighted')
print("Weighted F1 Score:", weighted_f1)
# Out:
# F1 Score: 0.31675893650468184
# Weighted F1 Score: 0.8602515623972741

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, cross_val_score
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.svm import SVC
import numpy as np
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Start time
start_time = time.time()

# Data preprocessing and splitting
train_df_inputs, test_df_inputs, train_df_output, test_df_output = train_test_split(df_inputs, df_output, test_size=0.25, random_state=45)

# End time
end_time = time.time()

# Time taken for data preprocessing and splitting
data_preprocessing_time = end_time - start_time

# Memory usage after data preprocessing
data_preprocessing_memory = memory_usage()

# Decision Tree
dt_start_time = time.time()
dt_model = DecisionTreeClassifier(criterion='gini', random_state=45007, max_depth=3)
dt_model.fit(train_df_inputs, train_df_output)
dt_training_time = time.time() - dt_start_time
dt_memory_used = memory_usage()
dt_pred = dt_model.predict(test_df_inputs)
dt_accuracy = accuracy_score(test_df_output, dt_pred)

# Cross-validation for Decision Tree
dtc_cv_start_time = time.time()
dtc_cv = DecisionTreeClassifier(criterion='gini', random_state=45045)
cv_scores_dtc = cross_val_score(dtc_cv, df_inputs, df_output.values.ravel(), cv=20)
dtc_cv_time = time.time() - dtc_cv_start_time
dtc_cv_accuracy = np.mean(cv_scores_dtc)

print("Decision Tree:")
print(f"  - Training Time (s): {dt_training_time}")
print(f"  - Memory Used (MB): {dt_memory_used}")
print(f"  - Single Split Accuracy: {dt_accuracy}")
print(f"  - Cross Validation Accuracy: {dtc_cv_accuracy}")
print()
# Out:
# Decision Tree:
#   - Training Time (s): 0.0556340217590332
#   - Memory Used (MB): 335.41015625
#   - Single Split Accuracy: 0.9025705133213532
#   - Cross Validation Accuracy: 0.8195304257033997

# %% [markdown]
# Random Forest

# %%
## Data Visualization Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from wordcloud import WordCloud
from collections import Counter
from scipy import stats
from sklearn.tree import plot_tree
import graphviz
from IPython.display import display
from collections import Counter

## Machine Learning Models and Evaluation Metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.validation import column_or_1d
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score, precision_recall_fscore_support
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression, Lasso, Ridge
from sklearn.metrics import make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.tree import export_graphviz

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=45056)

# %%
rf_classifier.fit(train_df_inputs, train_df_output['cluster_number'])
# Out:
# RandomForestClassifier(random_state=45056)

# %%
y_train_pred_rf = rf_classifier.predict(train_df_inputs)
y_test_pred_rf = rf_classifier.predict(test_df_inputs)

# %%
# Train the Random Forest classifier
rf_classifier.fit(train_df_inputs, train_df_output['cluster_number'])

# Print feature importances
feature_importances = rf_classifier.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': train_df_inputs.columns, 'Importance': feature_importances})
sorted_feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
print("Feature Importances:")
print(sorted_feature_importance_df)
# Out:
# Feature Importances:
#          Feature  Importance
# 3         profit    0.251586
# 6  shipping_cost    0.248389
# 5          sales    0.225221
# 2        weeknum    0.160762
# 4       quantity    0.071408
# 1           year    0.042634
# 0      ji_lu_shu    0.000000

# %%
# For training set
print("Training Set Confusion Matrix:")
print(confusion_matrix(train_df_output['cluster_number'], y_train_pred_rf))

print("\nTraining Set Classification Report:")
print(classification_report(train_df_output['cluster_number'], y_train_pred_rf))
# Out:
# Training Set Confusion Matrix:
# [[ 3297     0     0]
#  [    0 34793     0]
#  [    0     0   305]]
#
# Training Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3297
#            1       1.00      1.00      1.00     34793
#            2       1.00      1.00      1.00       305
#
#     accuracy                           1.00     38395
#    macro avg       1.00      1.00      1.00     38395
# weighted avg       1.00      1.00      1.00     38395

# %%
# For testing set
print("\nTesting Set Confusion Matrix:")
print(confusion_matrix(test_df_output['cluster_number'], y_test_pred_rf))

print("\nTesting Set Classification Report:")
print(classification_report(test_df_output['cluster_number'], y_test_pred_rf))
# Out:
# Testing Set Confusion Matrix:
# [[   15  1118     0]
#  [   26 11526     0]
#  [    0   114     0]]
#
# Testing Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.37      0.01      0.03      1133
#            1       0.90      1.00      0.95     11552
#            2       0.00      0.00      0.00       114
#
#     accuracy                           0.90     12799
#    macro avg       0.42      0.34      0.32     12799
# weighted avg       0.85      0.90      0.86     12799
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Assuming rf is your trained Random Forest classifier
for i in range(3):
    tree = rf_classifier.estimators_[i]  # Assuming rf_classifier is your trained Random Forest model
    dot_data = export_graphviz(tree,
                               feature_names=train_df_inputs.columns,
                               filled=True,
                               max_depth=2,
                               impurity=False,
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %%
# Export and visualize the first three decision trees
for i in range(3):
    tree = rf_classifier.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=train_df_inputs.columns,
                               filled=True,
                               max_depth=2,
                               impurity=False,
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %%
# Initialize a dictionary to store tree frequencies and rules
tree_frequency = Counter()
tree_rules = {}

# Loop through the trees and count their frequency while storing rules
for i in range(len(rf_classifier.estimators_)):
    tree = rf_classifier.estimators_[i]
    tree_str = export_text(tree, feature_names=list(train_df_inputs.columns))
    tree_frequency[tree_str] += 1
    tree_rules[tree_str] = tree

# Get the three most frequent trees
top_trees = tree_frequency.most_common(3)

# Print the rules for the top three trees
for tree_str, frequency in top_trees:
    print(f"Tree Frequency: {frequency}")
    print(tree_str)
    print("\n")
# Out:
# Tree Frequency: 1
# |--- profit <= 63.63
# |   |--- sales <= 112.50
# |   |   |--- profit <= 22.55
# |   |   |   |--- shipping_cost <= 0.11
# |   |   |   |   |--- profit <= -2.28
# |   |   |   |   |   |--- shipping_cost <= 0.05
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- shipping_cost >  0.05
# |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |--- sales <= 4.50
# |   |   |   |   |   |   |   |   |--- sales <= 2.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- sales >  2.50
# |   |   |   |   |   |   |   |   |   |--- profit <= -3.27
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- profit >  -3.27
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- sales >  4.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- profit >  -2.28
# |   |   |   |   |   |--- profit <= 0.08
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- profit >  0.08
# |   |   |   |   |   |   |--- sales <= 26.50
# |   |   |   |   |   |   |   |--- sales <= 9.50
# |   |   |   |   |   |   |   |   |--- year <= 2012.50
# |   |   |   |   |   |   |   |   |   |--- sales <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- sales >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 36.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  36.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- year >  2012.50
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 31.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- weeknum >  31.50
# |   |   |   |   |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- sales >  9.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- sales >  26.50
# |   |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |   |--- quantity <= 5.50
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 15.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- weeknum >  15.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- quantity >  5.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- shipping_cost >  0.11
# |   |   |   |   |--- quantity <= 2.50
# |   |   |   |   |   |--- profit <= 1.29
# |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |--- weeknum <= 30.50
# |   |   |   |   |   |   |   |   |--- profit <= -4.96
# |   |   |   |   |   |   |   |   |   |--- sales <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- year >  2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- sales >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= -29.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- profit >  -29.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |--- profit >  -4.96
# |   |   |   |   |   |   |   |   |   |--- profit <= -4.93
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- profit >  -4.93
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 72.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- sales >  72.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |--- weeknum >  30.50
# |   |   |   |   |   |   |   |   |--- sales <= 32.50
# |   |   |   |   |   |   |   |   |   |--- sales <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 43.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  43.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- sales >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 31.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  31.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |--- sales >  32.50
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 40.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 7.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  7.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- weeknum >  40.50
# |   |   |   |   |   |   |   |   |   |   |--- year <= 2012.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- year >  2012.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |--- weeknum <= 16.50
# |   |   |   |   |   |   |   |   |--- sales <= 59.50
# |   |   |   |   |   |   |   |   |   |--- sales <= 7.50
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- sales >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- sales >  7.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- sales >  59.50
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 6.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  6.36
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- weeknum >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- weeknum >  16.50
# |   |   |   |   |   |   |   |   |--- weeknum <= 18.50
# |   |   |   |   |   |   |   |   |   |--- sales <= 8.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- sales >  8.50
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- weeknum >  18.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 2.97
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 46.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  46.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  2.97
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 34.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  34.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |--- profit >  1.29
# |   |   |   |   |   |   |--- shipping_cost <= 15.81
# |   |   |   |   |   |   |   |--- sales <= 11.50
# |   |   |   |   |   |   |   |   |--- quantity <= 1.50
# |   |   |   |   |   |   |   |   |   |--- profit <= 2.97
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- profit >  2.97
# |   |   |   |   |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- year >  2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- quantity >  1.50
# |   |   |   |   |   |   |   |   |   |--- profit <= 2.57
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 26.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  26.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- profit >  2.57
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 43.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  43.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |--- sales >  11.50
# |   |   |   |   |   |   |   |   |--- sales <= 97.50
# |   |   |   |   |   |   |   |   |   |--- year <= 2012.50
# |   |   |   |   |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- year >  2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |--- year >  2012.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 0.87
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  0.87
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 22
# |   |   |   |   |   |   |   |   |--- sales >  97.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- shipping_cost >  15.81
# |   |   |   |   |   |   |   |--- sales <= 84.50
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 15.86
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  15.86
# |   |   |   |   |   |   |   |   |   |--- sales <= 83.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- sales >  83.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |--- sales >  84.50
# |   |   |   |   |   |   |   |   |--- profit <= 21.60
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- profit >  21.60
# |   |   |   |   |   |   |   |   |   |--- profit <= 21.78
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- profit >  21.78
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- quantity >  2.50
# |   |   |   |   |   |--- weeknum <= 4.50
# |   |   |   |   |   |   |--- shipping_cost <= 31.69
# |   |   |   |   |   |   |   |--- sales <= 108.50
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 3.32
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  3.32
# |   |   |   |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 11.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- profit >  11.12
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- year >  2011.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 3.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  3.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sales >  108.50
# |   |   |   |   |   |   |   |   |--- sales <= 111.00
# |   |   |   |   |   |   |   |   |   |--- year <= 2012.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- year >  2012.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- sales >  111.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- shipping_cost >  31.69
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- weeknum >  4.50
# |   |   |   |   |   |   |--- profit <= 4.91
# |   |   |   |   |   |   |   |--- quantity <= 6.50
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 27.94
# |   |   |   |   |   |   |   |   |   |--- year <= 2012.50
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- year >  2012.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 32.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  32.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |--- shipping_cost >  27.94
# |   |   |   |   |   |   |   |   |   |--- profit <= -77.78
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- profit >  -77.78
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 89.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- sales >  89.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- quantity >  6.50
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 1.22
# |   |   |   |   |   |   |   |   |   |--- profit <= 1.45
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- profit >  1.45
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  1.22
# |   |   |   |   |   |   |   |   |   |--- sales <= 61.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 7.66
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  7.66
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- sales >  61.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 1.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  1.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- profit >  4.91
# |   |   |   |   |   |   |   |--- shipping_cost <= 0.70
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- shipping_cost >  0.70
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 1.25
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 36.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 0.74
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  0.74
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- weeknum >  36.50
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 24.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- sales >  24.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- shipping_cost >  1.25
# |   |   |   |   |   |   |   |   |   |--- sales <= 13.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 2.20
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  2.20
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- sales >  13.50
# |   |   |   |   |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 22
# |   |   |   |   |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |--- profit >  22.55
# |   |   |   |--- quantity <= 1.50
# |   |   |   |   |--- sales <= 61.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- sales >  61.50
# |   |   |   |   |   |--- shipping_cost <= 5.37
# |   |   |   |   |   |   |--- sales <= 84.50
# |   |   |   |   |   |   |   |--- shipping_cost <= 4.67
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 2.11
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 0.38
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  0.38
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  2.11
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 24.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- weeknum >  24.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 23.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- profit >  23.38
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- shipping_cost >  4.67
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- sales >  84.50
# |   |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |   |--- weeknum <= 14.50
# |   |   |   |   |   |   |   |   |   |--- year <= 2012.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- year >  2012.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 12.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  12.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- weeknum >  14.50
# |   |   |   |   |   |   |   |   |   |--- profit <= 41.23
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- profit >  41.23
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |   |--- weeknum <= 39.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 3.66
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  3.66
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- weeknum >  39.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- shipping_cost >  5.37
# |   |   |   |   |   |   |--- weeknum <= 13.00
# |   |   |   |   |   |   |   |--- weeknum <= 8.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- weeknum >  8.50
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 15.74
# |   |   |   |   |   |   |   |   |   |--- profit <= 24.78
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- profit >  24.78
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  15.74
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- weeknum >  13.00
# |   |   |   |   |   |   |   |--- profit <= 24.33
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 7.40
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  7.40
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- profit >  24.33
# |   |   |   |   |   |   |   |   |--- profit <= 35.20
# |   |   |   |   |   |   |   |   |   |--- profit <= 26.45
# |   |   |   |   |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- profit >  26.45
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- profit >  35.20
# |   |   |   |   |   |   |   |   |   |--- sales <= 93.50
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 87.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- sales >  87.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- sales >  93.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- quantity >  1.50
# |   |   |   |   |--- shipping_cost <= 40.18
# |   |   |   |   |   |--- quantity <= 4.50
# |   |   |   |   |   |   |--- profit <= 22.61
# |   |   |   |   |   |   |   |--- profit <= 22.59
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- profit >  22.59
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- profit >  22.61
# |   |   |   |   |   |   |   |--- weeknum <= 19.50
# |   |   |   |   |   |   |   |   |--- sales <= 61.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- sales >  61.50
# |   |   |   |   |   |   |   |   |   |--- sales <= 62.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- sales >  62.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 16.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  16.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |--- weeknum >  19.50
# |   |   |   |   |   |   |   |   |--- profit <= 23.65
# |   |   |   |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- year >  2011.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- profit >  23.65
# |   |   |   |   |   |   |   |   |   |--- sales <= 106.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 24.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  24.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |--- sales >  106.50
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |--- quantity >  4.50
# |   |   |   |   |   |   |--- sales <= 63.50
# |   |   |   |   |   |   |   |--- profit <= 22.59
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- profit >  22.59
# |   |   |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 2.08
# |   |   |   |   |   |   |   |   |   |   |--- year <= 2012.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- year >  2012.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  2.08
# |   |   |   |   |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- year >  2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 8.12
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  8.12
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 9.18
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  9.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- sales >  63.50
# |   |   |   |   |   |   |   |--- sales <= 106.50
# |   |   |   |   |   |   |   |   |--- weeknum <= 34.50
# |   |   |   |   |   |   |   |   |   |--- profit <= 24.72
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 24.59
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  24.59
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- profit >  24.72
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- weeknum >  34.50
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 35.50
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 96.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- sales >  96.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- weeknum >  35.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 22.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- profit >  22.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |--- sales >  106.50
# |   |   |   |   |   |   |   |   |--- year <= 2012.50
# |   |   |   |   |   |   |   |   |   |--- quantity <= 7.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 36.37
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  36.37
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- quantity >  7.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- year >  2012.50
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 12.50
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 7.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  7.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- weeknum >  12.50
# |   |   |   |   |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |--- shipping_cost >  40.18
# |   |   |   |   |   |--- profit <= 33.56
# |   |   |   |   |   |   |--- sales <= 105.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- sales >  105.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- profit >  33.56
# |   |   |   |   |   |   |--- class: 1.0
# |   |--- sales >  112.50
# |   |   |--- weeknum <= 3.50
# |   |   |   |--- quantity <= 4.50
# |   |   |   |   |--- profit <= 14.40
# |   |   |   |   |   |--- profit <= 13.53
# |   |   |   |   |   |   |--- quantity <= 1.50
# |   |   |   |   |   |   |   |--- shipping_cost <= 21.84
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- shipping_cost >  21.84
# |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |--- quantity >  1.50
# |   |   |   |   |   |   |   |--- sales <= 328.50
# |   |   |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 29.27
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  29.27
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sales >  328.50
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 125.93
# |   |   |   |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 29.61
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  29.61
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= -79.87
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  -79.87
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  125.93
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- profit >  13.53
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- profit >  14.40
# |   |   |   |   |   |--- quantity <= 2.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- quantity >  2.50
# |   |   |   |   |   |   |--- sales <= 114.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- sales >  114.50
# |   |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |   |--- sales <= 262.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- sales >  262.00
# |   |   |   |   |   |   |   |   |   |--- quantity <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- quantity >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- quantity >  4.50
# |   |   |   |   |--- weeknum <= 1.50
# |   |   |   |   |   |--- shipping_cost <= 14.25
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- shipping_cost >  14.25
# |   |   |   |   |   |   |--- profit <= -7.49
# |   |   |   |   |   |   |   |--- shipping_cost <= 85.40
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- shipping_cost >  85.40
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- profit >  -7.49
# |   |   |   |   |   |   |   |--- sales <= 272.00
# |   |   |   |   |   |   |   |   |--- quantity <= 6.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- quantity >  6.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sales >  272.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- weeknum >  1.50
# |   |   |   |   |   |--- profit <= 57.42
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- profit >  57.42
# |   |   |   |   |   |   |--- weeknum <= 2.50
# |   |   |   |   |   |   |   |--- sales <= 520.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sales >  520.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- weeknum >  2.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |--- weeknum >  3.50
# |   |   |   |--- profit <= -5.82
# |   |   |   |   |--- weeknum <= 44.50
# |   |   |   |   |   |--- shipping_cost <= 894.68
# |   |   |   |   |   |   |--- profit <= -7.35
# |   |   |   |   |   |   |   |--- sales <= 142.50
# |   |   |   |   |   |   |   |   |--- weeknum <= 15.50
# |   |   |   |   |   |   |   |   |   |--- year <= 2012.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- year >  2012.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 3.14
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  3.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- weeknum >  15.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 8.85
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 8.76
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  8.76
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  8.85
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 131.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- sales >  131.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- sales >  142.50
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 206.29
# |   |   |   |   |   |   |   |   |   |--- quantity <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 13.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  13.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |--- quantity >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 15.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  15.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |--- shipping_cost >  206.29
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 224.29
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  224.29
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 244.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  244.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |--- profit >  -7.35
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- shipping_cost >  894.68
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- weeknum >  44.50
# |   |   |   |   |   |--- sales <= 963.50
# |   |   |   |   |   |   |--- profit <= -117.88
# |   |   |   |   |   |   |   |--- quantity <= 6.50
# |   |   |   |   |   |   |   |   |--- sales <= 388.50
# |   |   |   |   |   |   |   |   |   |--- sales <= 382.00
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 51.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  51.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- sales >  382.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- sales >  388.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- quantity >  6.50
# |   |   |   |   |   |   |   |   |--- profit <= -1251.55
# |   |   |   |   |   |   |   |   |   |--- profit <= -1515.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- profit >  -1515.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- profit >  -1251.55
# |   |   |   |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= -261.53
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  -261.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= -147.97
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- profit >  -147.97
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- profit >  -117.88
# |   |   |   |   |   |   |   |--- weeknum <= 47.50
# |   |   |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |   |   |--- sales <= 119.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- sales >  119.50
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 489.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- sales >  489.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- weeknum >  47.50
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 43.83
# |   |   |   |   |   |   |   |   |   |--- quantity <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 190.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- sales >  190.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- quantity >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  43.83
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- sales >  963.50
# |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |--- quantity <= 4.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- quantity >  4.50
# |   |   |   |   |   |   |   |   |--- weeknum <= 48.50
# |   |   |   |   |   |   |   |   |   |--- profit <= -78.92
# |   |   |   |   |   |   |   |   |   |   |--- profit <= -1026.60
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  -1026.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- profit >  -78.92
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- weeknum >  48.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |--- shipping_cost <= 92.84
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- shipping_cost >  92.84
# |   |   |   |   |   |   |   |   |--- weeknum <= 52.00
# |   |   |   |   |   |   |   |   |   |--- profit <= -1364.05
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- profit >  -1364.05
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 1125.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- sales >  1125.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- weeknum >  52.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- profit >  -5.82
# |   |   |   |   |--- sales <= 246.50
# |   |   |   |   |   |--- profit <= -5.72
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- profit >  -5.72
# |   |   |   |   |   |   |--- profit <= 48.34
# |   |   |   |   |   |   |   |--- quantity <= 3.50
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 88.94
# |   |   |   |   |   |   |   |   |   |--- quantity <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 29.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  29.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |--- quantity >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 48.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 21
# |   |   |   |   |   |   |   |   |   |   |--- profit >  48.21
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  88.94
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- quantity >  3.50
# |   |   |   |   |   |   |   |   |--- profit <= 48.31
# |   |   |   |   |   |   |   |   |   |--- profit <= 40.44
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 21
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- profit >  40.44
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 43.61
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- profit >  43.61
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- profit >  48.31
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- profit >  48.34
# |   |   |   |   |   |   |   |--- quantity <= 2.50
# |   |   |   |   |   |   |   |   |--- weeknum <= 5.50
# |   |   |   |   |   |   |   |   |   |--- sales <= 164.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- sales >  164.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- weeknum >  5.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 49.39
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 47.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  47.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  49.39
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 221.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- sales >  221.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- quantity >  2.50
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 4.78
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  4.78
# |   |   |   |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 52.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  52.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |--- sales >  246.50
# |   |   |   |   |   |--- sales <= 424.50
# |   |   |   |   |   |   |--- quantity <= 2.50
# |   |   |   |   |   |   |   |--- weeknum <= 22.50
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 19.70
# |   |   |   |   |   |   |   |   |   |--- quantity <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 298.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- sales >  298.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- quantity >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 60.74
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- profit >  60.74
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  19.70
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 21.50
# |   |   |   |   |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- year >  2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- weeknum >  21.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- weeknum >  22.50
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 18.64
# |   |   |   |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 16.79
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  16.79
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 4.51
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  4.51
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- shipping_cost >  18.64
# |   |   |   |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 1.50
# ...
# |   |   |   |   |   |   |   |--- shipping_cost >  117.37
# |   |   |   |   |   |   |   |   |--- quantity <= 6.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 123.93
# |   |   |   |   |   |   |   |   |   |   |--- year <= 2012.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |   |--- year >  2012.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  123.93
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |--- quantity >  6.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- weeknum >  48.50
# |   |   |   |   |   |   |   |--- quantity <= 7.50
# |   |   |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |   |   |--- profit <= 374.22
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- profit >  374.22
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- year >  2011.50
# |   |   |   |   |   |   |   |   |   |--- sales <= 1720.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- sales >  1720.00
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 935.26
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  935.26
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- quantity >  7.50
# |   |   |   |   |   |   |   |   |--- profit <= -921.98
# |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |--- profit >  -921.98
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 84.06
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  84.06
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 1573.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |   |--- sales >  1573.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |--- shipping_cost >  127.23
# |   |   |--- sales <= 634.00
# |   |   |   |--- quantity <= 4.50
# |   |   |   |   |--- profit <= 78.63
# |   |   |   |   |   |--- weeknum <= 4.50
# |   |   |   |   |   |   |--- shipping_cost <= 142.79
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- shipping_cost >  142.79
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- weeknum >  4.50
# |   |   |   |   |   |   |--- quantity <= 2.50
# |   |   |   |   |   |   |   |--- profit <= 9.59
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- profit >  9.59
# |   |   |   |   |   |   |   |   |--- profit <= 16.08
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- profit >  16.08
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 24.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- weeknum >  24.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- quantity >  2.50
# |   |   |   |   |   |   |   |--- profit <= 27.46
# |   |   |   |   |   |   |   |   |--- sales <= 474.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- sales >  474.50
# |   |   |   |   |   |   |   |   |   |--- sales <= 535.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- sales >  535.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 140.46
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  140.46
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- profit >  27.46
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- profit >  78.63
# |   |   |   |   |   |--- profit <= 105.92
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- profit >  105.92
# |   |   |   |   |   |   |--- profit <= 141.93
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- profit >  141.93
# |   |   |   |   |   |   |   |--- profit <= 173.52
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- profit >  173.52
# |   |   |   |   |   |   |   |   |--- sales <= 412.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- sales >  412.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 145.69
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  145.69
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 156.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  156.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |--- quantity >  4.50
# |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |--- weeknum <= 38.00
# |   |   |   |   |   |   |--- weeknum <= 23.00
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- weeknum >  23.00
# |   |   |   |   |   |   |   |--- sales <= 423.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sales >  423.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- weeknum >  38.00
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |--- sales >  634.00
# |   |   |   |--- quantity <= 1.50
# |   |   |   |   |--- weeknum <= 41.00
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- weeknum >  41.00
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- quantity >  1.50
# |   |   |   |   |--- shipping_cost <= 319.93
# |   |   |   |   |   |--- profit <= -32.87
# |   |   |   |   |   |   |--- quantity <= 5.50
# |   |   |   |   |   |   |   |--- weeknum <= 1.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- weeknum >  1.50
# |   |   |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |   |   |--- sales <= 1044.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- sales >  1044.00
# |   |   |   |   |   |   |   |   |   |   |--- profit <= -168.73
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  -168.73
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- year >  2011.50
# |   |   |   |   |   |   |   |   |   |--- profit <= -416.41
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- profit >  -416.41
# |   |   |   |   |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- quantity >  5.50
# |   |   |   |   |   |   |   |--- sales <= 1946.50
# |   |   |   |   |   |   |   |   |--- profit <= -82.18
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- profit >  -82.18
# |   |   |   |   |   |   |   |   |   |--- profit <= -66.15
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- profit >  -66.15
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sales >  1946.50
# |   |   |   |   |   |   |   |   |--- sales <= 2039.50
# |   |   |   |   |   |   |   |   |   |--- sales <= 2008.50
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 1966.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- sales >  1966.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- sales >  2008.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |--- sales >  2039.50
# |   |   |   |   |   |   |   |   |   |--- profit <= -1040.94
# |   |   |   |   |   |   |   |   |   |   |--- profit <= -1302.26
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  -1302.26
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- profit >  -1040.94
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- profit >  -32.87
# |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |--- quantity <= 4.50
# |   |   |   |   |   |   |   |   |--- sales <= 1393.00
# |   |   |   |   |   |   |   |   |   |--- sales <= 1255.00
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- sales >  1255.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- sales >  1393.00
# |   |   |   |   |   |   |   |   |   |--- quantity <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- quantity >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- quantity >  4.50
# |   |   |   |   |   |   |   |   |--- quantity <= 10.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 143.58
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 789.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |   |--- sales >  789.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  143.58
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 29.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  29.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |--- quantity >  10.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- year >  2011.50
# |   |   |   |   |   |   |   |--- quantity <= 9.50
# |   |   |   |   |   |   |   |   |--- profit <= -27.63
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- profit >  -27.63
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 16.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 360.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- profit >  360.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- weeknum >  16.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 129.97
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  129.97
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 22
# |   |   |   |   |   |   |   |--- quantity >  9.50
# |   |   |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 257.21
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 21.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  21.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  257.21
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- shipping_cost >  319.93
# |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |--- sales <= 1706.00
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- sales >  1706.00
# |   |   |   |   |   |   |   |--- weeknum <= 50.00
# |   |   |   |   |   |   |   |   |--- sales <= 4158.00
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 382.89
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 195.26
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  195.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  382.89
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 21.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  21.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- sales >  4158.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- weeknum >  50.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- year >  2011.50
# |   |   |   |   |   |   |--- sales <= 1272.50
# |   |   |   |   |   |   |   |--- quantity <= 3.50
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 433.29
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  433.29
# |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |--- quantity >  3.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- sales >  1272.50
# |   |   |   |   |   |   |   |--- profit <= 60.00
# |   |   |   |   |   |   |   |   |--- profit <= -302.96
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- profit >  -302.96
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 845.28
# |   |   |   |   |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  845.28
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- profit >  60.00
# |   |   |   |   |   |   |   |   |--- quantity <= 4.50
# |   |   |   |   |   |   |   |   |   |--- profit <= 424.71
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 351.95
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  351.95
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- profit >  424.71
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 21.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  21.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- quantity >  4.50
# |   |   |   |   |   |   |   |   |   |--- profit <= 67.53
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- profit >  67.53
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 382.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  382.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10

# %%
# Initialize a dictionary to store tree frequencies
tree_frequency = Counter()

# Loop through the trees and count their frequency
for i in range(len(rf_classifier.estimators_)):
    tree = rf_classifier.estimators_[i]
    tree_str = export_graphviz(tree, feature_names=train_df_inputs.columns,
                               filled=True, max_depth=2, impurity=False, proportion=True)
    tree_frequency[tree_str] += 1

# Get the three most frequent trees
top_trees = tree_frequency.most_common(3)

# Plot the top three trees
for tree_str, frequency in top_trees:
    graph = graphviz.Source(tree_str)
    display(graph)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from wordcloud import WordCloud
from collections import Counter
from scipy import stats
from sklearn.tree import plot_tree, export_graphviz
import graphviz
from IPython.display import display
from collections import Counter
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Start time
start_time = time.time()

# Initialize Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=45011)

# Train the Random Forest classifier
rf_classifier.fit(train_df_inputs, train_df_output['cluster_number'])

# Predictions
y_train_pred_rf = rf_classifier.predict(train_df_inputs)
y_test_pred_rf = rf_classifier.predict(test_df_inputs)

# End time
end_time = time.time()

# Time taken
execution_time = end_time - start_time

# Memory usage
memory_used = memory_usage()

# Accuracy
accuracy_train = accuracy_score(train_df_output['cluster_number'], y_train_pred_rf)
accuracy_test = accuracy_score(test_df_output['cluster_number'], y_test_pred_rf)

# Print time, memory usage, and accuracy
print("Time taken (seconds):", execution_time)
print("Memory used (MB):", memory_used)
print("Training Set Accuracy:", accuracy_train)
print("Testing Set Accuracy:", accuracy_test)

# Print feature importances
feature_importances = rf_classifier.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': train_df_inputs.columns, 'Importance': feature_importances})
sorted_feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
print("\nFeature Importances:")
print(sorted_feature_importance_df)

# Print confusion matrix and classification report for training set
print("\nTraining Set Confusion Matrix:")
print(confusion_matrix(train_df_output['cluster_number'], y_train_pred_rf))
print("\nTraining Set Classification Report:")
print(classification_report(train_df_output['cluster_number'], y_train_pred_rf))

# Print confusion matrix and classification report for testing set
print("\nTesting Set Confusion Matrix:")
print(confusion_matrix(test_df_output['cluster_number'], y_test_pred_rf))
print("\nTesting Set Classification Report:")
print(classification_report(test_df_output['cluster_number'], y_test_pred_rf))

# Export and visualize the first three decision trees
for i in range(3):
    tree = rf_classifier.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=train_df_inputs.columns,
                               filled=True,
                               max_depth=2,
                               impurity=False,
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# Initialize a dictionary to store tree frequencies and rules
tree_frequency = Counter()
tree_rules = {}

# Loop through the trees and count their frequency while storing rules
for i in range(len(rf_classifier.estimators_)):
    tree = rf_classifier.estimators_[i]
    tree_str = export_text(tree, feature_names=list(train_df_inputs.columns))
    tree_frequency[tree_str] += 1
    tree_rules[tree_str] = tree

# Get the three most frequent trees
top_trees = tree_frequency.most_common(3)

# Print the rules for the top three trees
for tree_str, frequency in top_trees:
    print(f"Tree Frequency: {frequency}")
    print(tree_str)
    print("\n")

# Initialize a dictionary to store tree frequencies
tree_frequency = Counter()

# Loop through the trees and count their frequency
for i in range(len(rf_classifier.estimators_)):
    tree = rf_classifier.estimators_[i]
    tree_str = export_graphviz(tree, feature_names=train_df_inputs.columns,
                               filled=True, max_depth=2, impurity=False, proportion=True)
    tree_frequency[tree_str] += 1

# Get the three most frequent trees
top_trees = tree_frequency.most_common(3)

# Plot the top three trees
for tree_str, frequency in top_trees:
    graph = graphviz.Source(tree_str)
    display(graph)
# Out:
# Time taken (seconds): 8.428425550460815
# Memory used (MB): 478.42578125
# Training Set Accuracy: 1.0
# Testing Set Accuracy: 0.9012422845534808
#
# Feature Importances:
#          Feature  Importance
# 3         profit    0.252795
# 6  shipping_cost    0.246630
# 5          sales    0.225084
# 2        weeknum    0.160356
# 4       quantity    0.071493
# 1           year    0.043640
# 0      ji_lu_shu    0.000000
#
# Training Set Confusion Matrix:
# [[ 3297     0     0]
#  [    0 34793     0]
#  [    0     0   305]]
#
# Training Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3297
#            1       1.00      1.00      1.00     34793
#            2       1.00      1.00      1.00       305
#
#     accuracy                           1.00     38395
#    macro avg       1.00      1.00      1.00     38395
# weighted avg       1.00      1.00      1.00     38395
#
#
# Testing Set Confusion Matrix:
# [[   13  1120     0]
#  [   30 11522     0]
#  [    0   114     0]]
#
# Testing Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.30      0.01      0.02      1133
#            1       0.90      1.00      0.95     11552
#            2       0.00      0.00      0.00       114
#
#     accuracy                           0.90     12799
#    macro avg       0.40      0.34      0.32     12799
# weighted avg       0.84      0.90      0.86     12799
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Tree Frequency: 1
# |--- shipping_cost <= 26.62
# |   |--- quantity <= 7.50
# |   |   |--- profit <= 55.83
# |   |   |   |--- profit <= 22.31
# |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |--- sales <= 118.50
# |   |   |   |   |   |   |--- sales <= 19.50
# |   |   |   |   |   |   |   |--- shipping_cost <= 0.07
# |   |   |   |   |   |   |   |   |--- profit <= 0.08
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- profit >  0.08
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- shipping_cost >  0.07
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 6.12
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 1.43
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 1.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  1.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  1.43
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 2.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  2.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- shipping_cost >  6.12
# |   |   |   |   |   |   |   |   |   |--- year <= 2012.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- year >  2012.50
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 18.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- sales >  18.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- sales >  19.50
# |   |   |   |   |   |   |   |--- shipping_cost <= 0.09
# |   |   |   |   |   |   |   |   |--- year <= 2012.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- year >  2012.50
# |   |   |   |   |   |   |   |   |   |--- profit <= 7.07
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- profit >  7.07
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- shipping_cost >  0.09
# |   |   |   |   |   |   |   |   |--- weeknum <= 18.50
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 8.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  8.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- weeknum >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 4.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  4.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |--- weeknum >  18.50
# |   |   |   |   |   |   |   |   |   |--- profit <= 5.56
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 30.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- sales >  30.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 24
# |   |   |   |   |   |   |   |   |   |--- profit >  5.56
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 14.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 21
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  14.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |--- sales >  118.50
# |   |   |   |   |   |   |--- weeknum <= 2.50
# |   |   |   |   |   |   |   |--- shipping_cost <= 22.08
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 17.47
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  17.47
# |   |   |   |   |   |   |   |   |   |--- quantity <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 245.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- sales >  245.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- quantity >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- shipping_cost >  22.08
# |   |   |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- year >  2011.50
# |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |--- weeknum >  2.50
# |   |   |   |   |   |   |   |--- sales <= 122.50
# |   |   |   |   |   |   |   |   |--- quantity <= 5.50
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 48.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 4.99
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  4.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- weeknum >  48.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 11.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  11.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- quantity >  5.50
# |   |   |   |   |   |   |   |   |   |--- year <= 2012.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- year >  2012.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 10.94
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  10.94
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |--- sales >  122.50
# |   |   |   |   |   |   |   |   |--- quantity <= 3.50
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 6.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- weeknum >  6.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= -0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- profit >  -0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |--- quantity >  3.50
# |   |   |   |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- year >  2011.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |--- sales <= 119.50
# |   |   |   |   |   |   |--- profit <= -185.22
# |   |   |   |   |   |   |   |--- quantity <= 2.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- quantity >  2.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- profit >  -185.22
# |   |   |   |   |   |   |   |--- profit <= 1.58
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 0.07
# |   |   |   |   |   |   |   |   |   |--- sales <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= -2.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  -2.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- sales >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  0.07
# |   |   |   |   |   |   |   |   |   |--- sales <= 25.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |--- sales >  25.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 1.54
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 22
# |   |   |   |   |   |   |   |   |   |   |--- profit >  1.54
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- profit >  1.58
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 8.86
# |   |   |   |   |   |   |   |   |   |--- quantity <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 19.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  19.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 21
# |   |   |   |   |   |   |   |   |   |--- quantity >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- sales >  9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |--- shipping_cost >  8.86
# |   |   |   |   |   |   |   |   |   |--- profit <= 9.40
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 2.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  2.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- profit >  9.40
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 9.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  9.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |--- sales >  119.50
# |   |   |   |   |   |   |--- profit <= -55.06
# |   |   |   |   |   |   |   |--- weeknum <= 29.50
# |   |   |   |   |   |   |   |   |--- profit <= -118.95
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 25.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 19.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  19.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- weeknum >  25.50
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 171.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- sales >  171.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- profit >  -118.95
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- weeknum >  29.50
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 12.96
# |   |   |   |   |   |   |   |   |   |--- profit <= -83.01
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- profit >  -83.01
# |   |   |   |   |   |   |   |   |   |   |--- profit <= -79.08
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  -79.08
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  12.96
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- profit >  -55.06
# |   |   |   |   |   |   |   |--- sales <= 340.50
# |   |   |   |   |   |   |   |   |--- profit <= -55.02
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- profit >  -55.02
# |   |   |   |   |   |   |   |   |   |--- quantity <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 37.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  37.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- quantity >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 25.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  25.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- sales >  340.50
# |   |   |   |   |   |   |   |   |--- sales <= 343.00
# |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |--- sales >  343.00
# |   |   |   |   |   |   |   |   |   |--- sales <= 351.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 20.74
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  20.74
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- sales >  351.50
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |--- profit >  22.31
# |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |--- sales <= 112.50
# |   |   |   |   |   |   |--- weeknum <= 4.50
# |   |   |   |   |   |   |   |--- weeknum <= 3.50
# |   |   |   |   |   |   |   |   |--- profit <= 24.55
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 6.25
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  6.25
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 79.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- sales >  79.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- profit >  24.55
# |   |   |   |   |   |   |   |   |   |--- profit <= 34.16
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- profit >  34.16
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 84.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- sales >  84.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- weeknum >  3.50
# |   |   |   |   |   |   |   |   |--- quantity <= 3.00
# |   |   |   |   |   |   |   |   |   |--- sales <= 104.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 5.26
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  5.26
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- sales >  104.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- quantity >  3.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- weeknum >  4.50
# |   |   |   |   |   |   |   |--- profit <= 23.22
# |   |   |   |   |   |   |   |   |--- profit <= 23.17
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 5.53
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 5.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  5.49
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  5.53
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 9.93
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  9.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- profit >  23.17
# |   |   |   |   |   |   |   |   |   |--- sales <= 81.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- sales >  81.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- profit >  23.22
# |   |   |   |   |   |   |   |   |--- sales <= 57.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 4.05
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 50.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- sales >  50.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  4.05
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- sales >  57.50
# |   |   |   |   |   |   |   |   |   |--- profit <= 31.00
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 7.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  7.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- profit >  31.00
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 32.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- profit >  32.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |--- sales >  112.50
# |   |   |   |   |   |   |--- quantity <= 2.50
# |   |   |   |   |   |   |   |--- profit <= 25.04
# |   |   |   |   |   |   |   |   |--- quantity <= 1.50
# |   |   |   |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 146.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- sales >  146.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- year >  2011.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 13.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  13.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- quantity >  1.50
# |   |   |   |   |   |   |   |   |   |--- sales <= 235.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- sales >  235.00
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 6.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  6.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- profit >  25.04
# |   |   |   |   |   |   |   |   |--- year <= 2012.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 23.99
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 37.86
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- profit >  37.86
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  23.99
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 24.66
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  24.66
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- year >  2012.50
# |   |   |   |   |   |   |   |   |   |--- profit <= 51.77
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- profit >  51.77
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- quantity >  2.50
# |   |   |   |   |   |   |   |--- weeknum <= 2.50
# |   |   |   |   |   |   |   |   |--- sales <= 114.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- sales >  114.50
# |   |   |   |   |   |   |   |   |   |--- profit <= 33.93
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- profit >  33.93
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 14.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  14.36
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- weeknum >  2.50
# |   |   |   |   |   |   |   |   |--- sales <= 344.50
# |   |   |   |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- year >  2011.50
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 113.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- sales >  113.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |--- sales >  344.50
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 51.00
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 4.64
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  4.64
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- weeknum >  51.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |--- profit <= 22.32
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- profit >  22.32
# |   |   |   |   |   |   |--- weeknum <= 12.50
# |   |   |   |   |   |   |   |--- sales <= 230.00
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 11.32
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 11.22
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 11.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  11.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  11.22
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  11.32
# |   |   |   |   |   |   |   |   |   |--- quantity <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 25.16
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  25.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- quantity >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sales >  230.00
# |   |   |   |   |   |   |   |   |--- weeknum <= 9.00
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 24.59
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 330.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- sales >  330.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  24.59
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 33.18
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  33.18
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- weeknum >  9.00
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 11.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- weeknum >  11.50
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- weeknum >  12.50
# |   |   |   |   |   |   |   |--- shipping_cost <= 21.22
# |   |   |   |   |   |   |   |   |--- sales <= 692.50
# |   |   |   |   |   |   |   |   |   |--- quantity <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- quantity >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- sales >  692.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- shipping_cost >  21.22
# |   |   |   |   |   |   |   |   |--- quantity <= 5.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 21.24
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  21.24
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- quantity >  5.50
# |   |   |   |   |   |   |   |   |   |--- sales <= 105.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- sales >  105.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 25.83
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  25.83
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |--- profit >  55.83
# |   |   |   |--- year <= 2011.50
# |   |   |   |   |--- sales <= 236.00
# |   |   |   |   |   |--- quantity <= 2.50
# |   |   |   |   |   |   |--- profit <= 57.78
# |   |   |   |   |   |   |   |--- sales <= 151.50
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 9.57
# |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  9.57
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sales >  151.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- profit >  57.78
# |   |   |   |   |   |   |   |--- weeknum <= 44.50
# |   |   |   |   |   |   |   |   |--- profit <= 60.53
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- profit >  60.53
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 24.13
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  24.13
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- weeknum >  44.50
# |   |   |   |   |   |   |   |   |--- sales <= 133.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- sales >  133.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 11.20
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  11.20
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 63.69
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  63.69
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- quantity >  2.50
# |   |   |   |   |   |   |--- profit <= 93.68
# |   |   |   |   |   |   |   |--- shipping_cost <= 23.23
# |   |   |   |   |   |   |   |   |--- profit <= 78.66
# |   |   |   |   |   |   |   |   |   |--- profit <= 56.89
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 9.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  9.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- profit >  56.89
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- profit >  78.66
# |   |   |   |   |   |   |   |   |   |--- profit <= 78.94
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- profit >  78.94
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 85.65
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- profit >  85.65
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- shipping_cost >  23.23
# |   |   |   |   |   |   |   |   |--- profit <= 68.46
# |   |   |   |   |   |   |   |   |   |--- sales <= 178.00
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 4.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  4.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- sales >  178.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- profit >  68.46
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- profit >  93.68
# |   |   |   |   |   |   |   |--- quantity <= 5.50
# |   |   |   |   |   |   |   |   |--- profit <= 97.22
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 32.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- weeknum >  32.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- profit >  97.22
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- quantity >  5.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- sales >  236.00
# |   |   |   |   |   |--- sales <= 610.50
# |   |   |   |   |   |   |--- quantity <= 4.50
# |   |   |   |   |   |   |   |--- sales <= 319.00
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 24.95
# |   |   |   |   |   |   |   |   |   |--- sales <= 317.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 67.63
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  67.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- sales >  317.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  24.95
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sales >  319.00
# |   |   |   |   |   |   |   |   |--- profit <= 106.06
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 18.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 63.53
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  63.53
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  18.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- profit >  106.06
# |   |   |   |   |   |   |   |   |   |--- sales <= 517.50
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- sales >  517.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 159.60
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  159.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- quantity >  4.50
# |   |   |   |   |   |   |   |--- sales <= 529.50
# |   |   |   |   |   |   |   |   |--- weeknum <= 41.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- weeknum >  41.50
# |   |   |   |   |   |   |   |   |   |--- quantity <= 6.50
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- quantity >  6.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sales >  529.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- sales >  610.50
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- year >  2011.50
# |   |   |   |   |--- shipping_cost <= 4.79
# |   |   |   |   |   |--- profit <= 147.44
# |   |   |   |   |   |   |--- quantity <= 2.50
# |   |   |   |   |   |   |   |--- shipping_cost <= 1.20
# |   |   |   |   |   |   |   |   |--- weeknum <= 36.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- weeknum >  36.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- shipping_cost >  1.20
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- quantity >  2.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- profit >  147.44
# |   |   |   |   |   |   |--- profit <= 240.26
# |   |   |   |   |   |   |   |--- sales <= 539.00
# |   |   |   |   |   |   |   |   |--- sales <= 346.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- sales >  346.00
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sales >  539.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- profit >  240.26
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- shipping_cost >  4.79
# |   |   |   |   |   |--- profit <= 190.53
# |   |   |   |   |   |   |--- quantity <= 2.50
# |   |   |   |   |   |   |   |--- sales <= 348.50
# |   |   |   |   |   |   |   |   |--- profit <= 104.71
# |   |   |   |   |   |   |   |   |   |--- sales <= 337.00
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 13.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  13.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- sales >  337.00
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 346.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- sales >  346.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- profit >  104.71
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 15.78
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 267.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- sales >  267.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  15.78
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 263.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- sales >  263.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- sales >  348.50
# |   |   |   |   |   |   |   |   |--- weeknum <= 38.00
# |   |   |   |   |   |   |   |   |   |--- sales <= 436.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- sales >  436.50
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- weeknum >  38.00
# |   |   |   |   |   |   |   |   |   |--- profit <= 93.14
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 384.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- sales >  384.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- profit >  93.14
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- quantity >  2.50
# |   |   |   |   |   |   |   |--- sales <= 119.50
# |   |   |   |   |   |   |   |   |--- quantity <= 5.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- quantity >  5.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- sales >  119.50
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 4.98
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  4.98
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 11.56
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 56.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  56.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  11.56
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 63.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- profit >  63.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |--- profit >  190.53
# |   |   |   |   |   |   |--- quantity <= 2.50
# |   |   |   |   |   |   |   |--- quantity <= 1.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- quantity >  1.50
# |   |   |   |   |   |   |   |   |--- weeknum <= 37.50
# |   |   |   |   |   |   |   |   |   |--- sales <= 727.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- sales >  727.00
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 27.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  27.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- weeknum >  37.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- quantity >  2.50
# |   |   |   |   |   |   |   |--- sales <= 1132.00
# |   |   |   |   |   |   |   |   |--- weeknum <= 41.50
# |   |   |   |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 23.14
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  23.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- weeknum >  41.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 20.30
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  20.30
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 211.88
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  211.88
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sales >  1132.00
# |   |   |   |   |   |   |   |   |--- sales <= 1583.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 25.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  25.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- sales >  1583.50
# |   |   |   |   |   |   |   |   |   |--- sales <= 3158.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- sales >  3158.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 18.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  18.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |--- quantity >  7.50
# |   |   |--- shipping_cost <= 0.13
# |   |   |   |--- shipping_cost <= 0.06
# |   |   |   |   |--- class: 1.0
# |   |   |   |--- shipping_cost >  0.06
# |   |   |   |   |--- class: 0.0
# |   |   |--- shipping_cost >  0.13
# |   |   |   |--- weeknum <= 43.50
# |   |   |   |   |--- profit <= -32.72
# |   |   |   |   |   |--- shipping_cost <= 2.49
# |   |   |   |   |   |   |--- shipping_cost <= 0.92
# |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |--- shipping_cost >  0.92
# |   |   |   |   |   |   |   |--- weeknum <= 18.00
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- weeknum >  18.00
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- shipping_cost >  2.49
# |   |   |   |   |   |   |--- weeknum <= 42.50
# |   |   |   |   |   |   |   |--- shipping_cost <= 5.10
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 4.97
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  4.97
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- shipping_cost >  5.10
# |   |   |   |   |   |   |   |   |--- quantity <= 9.50
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 39.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- weeknum >  39.50
# |   |   |   |   |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- year >  2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- quantity >  9.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- weeknum >  42.50
# |   |   |   |   |   |   |   |--- profit <= -135.25
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- profit >  -135.25
# |   |   |   |   |   |   |   |   |--- sales <= 195.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- sales >  195.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- profit >  -32.72
# |   |   |   |   |   |--- profit <= -8.81
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- profit >  -8.81
# |   |   |   |   |   |   |--- profit <= -8.35
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- profit >  -8.35
# |   |   |   |   |   |   |   |--- year <= 2012.50
# |   |   |   |   |   |   |   |   |--- sales <= 30.00
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 2.84
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  2.84
# |   |   |   |   |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- year >  2011.50
# ...
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- weeknum >  10.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 26.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  26.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 98.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- profit >  98.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |--- sales >  496.50
# |   |   |   |   |   |   |   |   |--- quantity <= 4.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 31.45
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 151.79
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- profit >  151.79
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  31.45
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 34.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  34.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |--- quantity >  4.50
# |   |   |   |   |   |   |   |   |   |--- year <= 2012.50
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 683.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- sales >  683.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |--- year >  2012.50
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |--- quantity <= 5.50
# |   |   |   |   |   |   |   |   |--- profit <= 59.70
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 38.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 27.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  27.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- weeknum >  38.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 55.08
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- profit >  55.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- profit >  59.70
# |   |   |   |   |   |   |   |   |   |--- sales <= 347.00
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 33.40
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  33.40
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- sales >  347.00
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |--- quantity >  5.50
# |   |   |   |   |   |   |   |   |--- sales <= 1170.00
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 31.98
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 308.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- sales >  308.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  31.98
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 28.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  28.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- sales >  1170.00
# |   |   |   |   |   |   |   |   |   |--- profit <= 555.43
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- profit >  555.43
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 109.84
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  109.84
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |--- quantity >  6.50
# |   |   |   |   |   |   |--- sales <= 545.00
# |   |   |   |   |   |   |   |--- sales <= 359.50
# |   |   |   |   |   |   |   |   |--- profit <= 59.30
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- profit >  59.30
# |   |   |   |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 37.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  37.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- year >  2011.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 148.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- profit >  148.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- sales >  359.50
# |   |   |   |   |   |   |   |   |--- quantity <= 8.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 63.88
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  63.88
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 428.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- sales >  428.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- quantity >  8.50
# |   |   |   |   |   |   |   |   |   |--- quantity <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 403.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- sales >  403.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- quantity >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 102.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- profit >  102.82
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- sales >  545.00
# |   |   |   |   |   |   |   |--- weeknum <= 51.50
# |   |   |   |   |   |   |   |   |--- year <= 2013.50
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 44.50
# |   |   |   |   |   |   |   |   |   |   |--- sales <= 965.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- sales >  965.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- weeknum >  44.50
# |   |   |   |   |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- year >  2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- year >  2013.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 39.75
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 23.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  23.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  39.75
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 67.55
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  67.55
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |--- weeknum >  51.50
# |   |   |   |   |   |   |   |   |--- quantity <= 8.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- quantity >  8.00
# |   |   |   |   |   |   |   |   |   |--- sales <= 882.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- sales >  882.00
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 66.95
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  66.95
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |--- shipping_cost >  127.70
# |   |   |   |   |--- sales <= 1012.50
# |   |   |   |   |   |--- profit <= 461.94
# |   |   |   |   |   |   |--- weeknum <= 15.50
# |   |   |   |   |   |   |   |--- weeknum <= 2.50
# |   |   |   |   |   |   |   |   |--- quantity <= 3.50
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- quantity >  3.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- weeknum >  2.50
# |   |   |   |   |   |   |   |   |--- quantity <= 7.50
# |   |   |   |   |   |   |   |   |   |--- quantity <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- quantity >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- quantity >  7.50
# |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 150.22
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- shipping_cost >  150.22
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- weeknum >  15.50
# |   |   |   |   |   |   |   |--- profit <= 121.79
# |   |   |   |   |   |   |   |   |--- quantity <= 11.00
# |   |   |   |   |   |   |   |   |   |--- sales <= 965.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 107.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- profit >  107.38
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- sales >  965.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- quantity >  11.00
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- profit >  121.79
# |   |   |   |   |   |   |   |   |--- sales <= 882.50
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 44.00
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 28.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  28.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- weeknum >  44.00
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 150.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  150.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- sales >  882.50
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 28.00
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost <= 201.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- shipping_cost >  201.69
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- weeknum >  28.00
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- profit >  461.94
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- sales >  1012.50
# |   |   |   |   |   |--- profit <= 72.28
# |   |   |   |   |   |   |--- shipping_cost <= 336.02
# |   |   |   |   |   |   |   |--- quantity <= 4.50
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- quantity >  4.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- shipping_cost >  336.02
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- profit >  72.28
# |   |   |   |   |   |   |--- sales <= 1013.50
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- sales >  1013.50
# |   |   |   |   |   |   |   |--- quantity <= 5.50
# |   |   |   |   |   |   |   |   |--- weeknum <= 12.50
# |   |   |   |   |   |   |   |   |   |--- weeknum <= 8.50
# |   |   |   |   |   |   |   |   |   |   |--- year <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- year >  2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- weeknum >  8.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 700.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- profit >  700.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- weeknum >  12.50
# |   |   |   |   |   |   |   |   |   |--- sales <= 1274.50
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- sales >  1274.50
# |   |   |   |   |   |   |   |   |   |   |--- profit <= 121.44
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- profit >  121.44
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |--- quantity >  5.50
# |   |   |   |   |   |   |   |   |--- shipping_cost <= 135.66
# |   |   |   |   |   |   |   |   |   |--- sales <= 1394.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- sales >  1394.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- shipping_cost >  135.66
# |   |   |   |   |   |   |   |   |   |--- profit <= 1020.24
# |   |   |   |   |   |   |   |   |   |   |--- weeknum <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- weeknum >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |--- profit >  1020.24
# |   |   |   |   |   |   |   |   |   |   |--- quantity <= 9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- quantity >  9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3

# %%
import pandas as pd
import numpy as np
import time
import psutil
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Data preprocessing and splitting
train_df_inputs, test_df_inputs, train_df_output, test_df_output = train_test_split(df_inputs, df_output, test_size=0.25, random_state=45)

# Initialize lists to store results
models = []
training_times = []
memory_used = []
single_split_accuracies = []
cross_validation_accuracies = []

# Decision Tree
dt_start_time = time.time()
dt_model = DecisionTreeClassifier(criterion='gini', random_state=45011, max_depth=3)
dt_model.fit(train_df_inputs, train_df_output)
dt_training_time = time.time() - dt_start_time
dt_memory_used = memory_usage()
dt_pred = dt_model.predict(test_df_inputs)
dt_accuracy = accuracy_score(test_df_output, dt_pred)

# Cross-validation for Decision Tree
dtc_cv_start_time = time.time()
dtc_cv = DecisionTreeClassifier(criterion='gini', random_state=45011)
cv_scores_dtc = cross_val_score(dtc_cv, df_inputs, df_output.values.ravel(), cv=20)
dtc_cv_time = time.time() - dtc_cv_start_time
dtc_cv_accuracy = np.mean(cv_scores_dtc)

# Append Decision Tree results to lists
models.append('Decision Tree')
training_times.append(dt_training_time)
memory_used.append(dt_memory_used)
single_split_accuracies.append(dt_accuracy)
cross_validation_accuracies.append(dtc_cv_accuracy)

# Random Forest
rf_start_time = time.time()
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=45011)
rf_classifier.fit(train_df_inputs, train_df_output['cluster_number'])
rf_training_time = time.time() - rf_start_time
rf_memory_used = memory_usage()
y_train_pred_rf = rf_classifier.predict(train_df_inputs)
y_test_pred_rf = rf_classifier.predict(test_df_inputs)
rf_accuracy_train = accuracy_score(train_df_output['cluster_number'], y_train_pred_rf)
rf_accuracy_test = accuracy_score(test_df_output['cluster_number'], y_test_pred_rf)

# Append Random Forest results to lists
models.append('Random Forest')
training_times.append(rf_training_time)
memory_used.append(rf_memory_used)
single_split_accuracies.append(rf_accuracy_test)  # Using test accuracy as we already calculated it
cross_validation_accuracies.append(np.nan)  # Cross-validation accuracy not calculated here

# Create DataFrame
results_df = pd.DataFrame({
    'Model': models,
    'Training Time (s)': training_times,
    'Memory Used (MB)': memory_used,
    'Single Split Accuracy': single_split_accuracies,
    'Cross Validation Accuracy': cross_validation_accuracies
})

# Print DataFrame
print(results_df)
# Out:
#            Model  Training Time (s)  Memory Used (MB)  Single Split Accuracy  \
# 0  Decision Tree           0.059876        480.746094               0.902571
# 1  Random Forest           6.807764        551.902344               0.901242
#
#    Cross Validation Accuracy
# 0                   0.818905
# 1                        NaN
